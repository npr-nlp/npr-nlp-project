# %%
import pandas as pd
import numpy as np

# %%
utterances = pd.read_csv('utterances.csv')
utterances.head()
# Out:
#    episode  episode_order                                            speaker  \
# 0    57264              9  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 1    57264             10  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 2    57264             11                                   NEAL CONAN, host
# 3    57264             12  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 4    57264             13                                   NEAL CONAN, host
#
#                                            utterance
# 0  It's a 2,200-mile race. To give some sense of ...
# 1  So for a top competitor like Lance to try to m...
# 2  So in every team, presumably there's one star,...
# 3  That's right. Each team has nine riders. And w...
# 4  So slipstream, this is like drafting in car ra...

# %%
print(utterances.utterance[0])
# Out:
# It's a 2,200-mile race. To give some sense of perspective, that's roughly the distance between Washington, D.C. and Las Vegas. They do it over the course of three weeks at very fast speeds. But incredibly, oftentimes the distance between first and second is somewhere between and one and three minutes.

# %%
utterances.shape
# Out:
# (3199858, 4)

# %%
utterances.sort_values(by=['episode','episode_order'])[0:50]
# Out:
#          episode  episode_order                    speaker  \
# 2313663        1              1  LULU GARCIA-NAVARRO, HOST
# 2313664        1              2  LULU GARCIA-NAVARRO, HOST
# 2313665        1              3       MARA LIASSON, BYLINE
# 2313666        1              4  LULU GARCIA-NAVARRO, HOST
# 2313667        1              5       MARA LIASSON, BYLINE
# 2313668        1              6  LULU GARCIA-NAVARRO, HOST
# 2313669        1              7       MARA LIASSON, BYLINE
# 2313670        1              8  LULU GARCIA-NAVARRO, HOST
# 2313767        1              9       MARA LIASSON, BYLINE
# 2313768        1             10  LULU GARCIA-NAVARRO, HOST
# 2313769        1             11       MARA LIASSON, BYLINE
# 1442211        2              1  LULU GARCIA-NAVARRO, HOST
# 1442212        2              2  LULU GARCIA-NAVARRO, HOST
# 1442213        2              3  LULU GARCIA-NAVARRO, HOST
# 1442214        2              4            ANNE DUNKELBERG
# ...

# %%
utterances.head(50)
# Out:
#     episode  episode_order                                            speaker  \
# 0     57264              9  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 1     57264             10  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 2     57264             11                                   NEAL CONAN, host
# 3     57264             12  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 4     57264             13                                   NEAL CONAN, host
# 5     57264             14  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 6     57264             15                                   NEAL CONAN, host
# 7     57264             16  Ms. LOREN MOONEY (Editor-in-Chief, Bicycling M...
# 8     57264             17                                   NEAL CONAN, host
# 9     57264             18                                      JOHN (Caller)
# 10    57264             19                                   NEAL CONAN, host
# ...

# %%
utterances2= pd.read_csv("utterances-2sp.csv")

# %%
utterances2.head(50)
# Out:
#     episode  episode_order  turn_order  speaker_order  host_id  is_host  \
# 0         1              1           0              0        0     True
# 1         1              1           1              0        0     True
# 2         1              1           2              0        0     True
# 3         1              1           3              0        0     True
# 4         1              2           0              0        0     True
# 5         1              3           0              1       -1    False
# 6         1              4           0              0        0     True
# 7         1              4           1              0        0     True
# 8         1              5           0              1       -1    False
# 9         1              5           1              1       -1    False
# 10        1              5           2              1       -1    False
# 11        1              5           3              1       -1    False
# ...

# %%
utterances2.shape
# Out:
# (1240112, 7)

# %%
utterances2.utterance[0]
# Out:
# "The impeachment inquiry picks up tomorrow where it left off Friday, with a subpoena sent to a White House that's used to ignoring congressional requests, a State Department that missed its own subpoena deadline and investigators poring over text messages between U.S. diplomats discussing what exactly the president wanted from Ukraine."

# %%
episodes = pd.read_csv('episodes.csv')
episodes.head()
# Out:
#       id          program                                              title  \
# 0  98814  Morning Edition  Senate Ushers In New Year With 'Fiscal Cliff' ...
# 1  98824  Morning Edition  Cheap Bubbly Or Expensive Sparkling Wine? Look...
# 2  98821  Morning Edition         U.S. Gas Prices Reach Record Level In 2012
# 3  98806  Morning Edition              House Approves 'Fiscal Cliff' Measure
# 4  98823  Morning Edition                     The Fiscal Cliff: A Love Story
#
#   episode_date
# 0   2013-01-01
# 1   2012-12-31
# 2   2013-01-01
# 3   2013-01-02
# 4   2012-12-31

# %%
episodes.id.value_counts()
# Out:
# 4098      1
# 33861     1
# 3156      1
# 9297      1
# 54351     1
#          ..
# 122257    1
# 120208    1
# 77199     1
# 75150     1
# 4094      1
# Name: id, Length: 105848, dtype: int64

# %%
headlines = pd.read_csv('headlines.csv')
headlines.head()
# Out:
#        id                                           headline
# 0  524288  For Some, The Decision To Enlist Offers Direction
# 1  524289          Whither The Astronauts Without A Shuttle?
# 2  524292      Tour Winner May Not Be First Over Finish Line
# 3  262153  California College Students Walk Out Of Class ...
# 4  524298               New Theory On 'Shaken Baby Syndrome'

# %%
headlines.shape
# Out:
# (97437, 2)

# %%
headlines.id.value_counts()
# Out:
# 524288    1
# 607618    1
# 605581    1
# 159858    1
# 593291    1
#          ..
# 92792     1
# 594551    1
# 596598    1
# 592500    1
# 526335    1
# Name: id, Length: 97437, dtype: int64

# %%
host_id = pd.read_json('host_id.json',typ='series')
host_id.head()
# Out:
# lulu garcia-navarro    0
# melissa block          1
# leila fadel            2
# susan davis            3
# sacha pfeiffer         4
# dtype: int64

# %%
host_map = pd.read_json('host-map.json')

# %%
host_map.head().T
# Out:
#                     name                                           episodes  \
# 0    lulu garcia-navarro  [512, 1, 2, 513, 515, 6, 518, 519, 6670, 6671,...
# 1          melissa block  [137216, 129027, 139267, 135177, 135178, 13722...
# 2            leila fadel     [75, 77, 79, 339, 83, 342, 344, 345, 349, 350]
# 3            susan davis                               [185, 563, 189, 191]
# 4         sacha pfeiffer  [387, 389, 391, 8085, 8088, 8089, 8090, 673, 6...
# ..                   ...                                                ...
# 271        howard berkes  [137921, 137923, 137705, 137707, 137709, 13771...
# 277      william zinsser                                           [138142]
# 281   text melissa block                                           [138861]
# 254      michelle norris                                   [138872, 138875]
# 267       michelle block                                           [138877]
#
#                                               programs
# ...
